# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
n_boat_gt = 4
n_anchors = 10

# %%
# From testing function (lets leave out batch for now)
reg_score = np.zeros((768, 768, n_anchors, 4))
class_score = numpy.random.rand(768, 768, n_anchors*2)
ground_truth_map = np.zeros((768, 768, n_boat_gt))


# Place some random GT boats
params = [(34,54,10,10), (100,200,100,20), (643,431,11,27), (250,250,20,30) ]
for i in range(n_boat_gt):
    
    params_i = params[i]
    ground_truth_map[params_i[0]:(params_i[0] + params_i[2]), params_i[1]:(params_i[1] + params_i[3]), i] = 1
    plt.imshow(ground_truth_map[:,:,i])
    plt.show()

# %%
# for each Ground truth, check all boxes with it to pass the IOU threshold
for i in range(n_boat_gt):
    gt_boat_map = ground_truth_map[:,:,i]
    for j in
